# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../WeatherPy/Output/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID        City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0      kodiak  57.7900 -152.4072     33.31       100         100
# 1        1  georgetown   5.4112  100.3354     82.33        85          20
# 2        2   geraldton -28.7667  114.6000     64.81        68           0
# 3        3   mahebourg -20.4081   57.7000     79.25        73          75
# 4        4      lompoc  34.6391 -120.4579     52.79        94         100
#
#    Wind Speed Country        Date
# 0        5.75      US  1673890046
# 1        8.05      MY  1673890392
# 2       14.97      AU  1673890488
# 3       14.97      MU  1673890488
# 4       12.66      US  1673890454

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
#map_plot = city_data_df.hvplot.points(
#    "Lng",
#    "Lat",
#    geo = True,
#    tiles = "City",
#    frame_width = 700,
#    frame_height = 500,
#    size = "Humidity",
#    scale = 0.01,
#    color = "City"
#)
# Display the map
#map_plot

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_cities = city_data_df.loc[(city_data_df["Humidity"] < 35) & (city_data_df["Max Temp"] > 60)\
    & (city_data_df["Max Temp"] < 90)]
# Drop any rows with null values
ideal_clean = ideal_cities.dropna()
# Display sample data
ideal_clean
# Out:
#      City_ID                City      Lat      Lng  Max Temp  Humidity  \
# 5          5              tahoua  14.8888   5.2692     82.38         9
# 11        11        umm kaddadah  13.6017  26.6876     66.96        21
# 84        84           taoudenni  22.6783  -3.9836     73.47        17
# 149      149                atar  20.5169 -13.0499     81.70        10
# 166      166         panguipulli -39.6333 -72.3333     77.79        22
# 198      198               kutum  14.2000  24.6667     64.87        20
# 251      251               adrar  20.5022 -10.0711     73.44        14
# 268      268               uyuni -20.4597 -66.8250     68.29        17
# 273      273               bilma  18.6853  12.9164     66.79        23
# 277      277  comodoro rivadavia -45.8667 -67.5000     75.06        25
# 278      278               zemio   5.0314  25.1361     79.48        24
# 290      290              rincon  32.2960 -81.2354     61.92        27
# 303      303              sindgi  16.9167  76.2333     74.23        29
# 330      330        dogondoutchi  13.6393   4.0287     76.50        15
# 381      381            tessalit  20.1986   1.0114     73.51        15
# 388      388               gambo   4.6482  22.2633     79.03        29
# 399      399         tallahassee  30.4383 -84.2807     64.99        34
# 420      420     sancti spiritus  21.9297 -79.4425     76.73        34
# 433      433          eucaliptus -17.5833 -67.5167     66.29        19
# 481      481      mount pleasant  32.7941 -79.8626     61.99        28
# 492      492          rio blanco  18.8333 -97.1500     80.76        26
# 530      530             kalavad  22.2167  70.3833     60.30        23
# 532      532             mangrol  21.1167  70.1167     63.72        33
# 533      533           colesberg -30.7200  25.0972     89.06        16
# 537      537             goundam  16.4145  -3.6708     78.39        11
# 539      539    pinheiro machado -31.5783 -53.3811     87.06        32
# 552      552             carahue -38.7000 -73.1667     72.84        31
# 556      556               keffi   8.8486   7.8736     87.71        14
# 558      558              beboto   8.2668  16.9390     81.23        18
# 572      572        birnin kebbi  12.4539   4.1975     78.57        15
#
#      Cloudiness  Wind Speed Country        Date
# 5             0        9.22      NE  1673890489
# 11           74       13.42      SD  1673890492
# 84            0        9.84      ML  1673890534
# 149          61       10.85      MR  1673890566
# 166          99        3.89      CL  1673890575
# 198          28       10.69      SD  1673890454
# 251          11       10.96      MR  1673890619
# 268          12       12.68      BO  1673890630
# 273          12        6.71      NE  1673890633
# 277           0       14.97      AR  1673890635
# 278          98        3.83      CF  1673890636
# 290          75        3.44      US  1673890416
# 303           0       11.25      IN  1673890651
# 330           5        8.70      NE  1673890664
# 381           0       10.13      ML  1673890691
# 388          84        2.30      CF  1673890695
# 399           0        3.44      US  1673890545
# 420           0        5.19      CU  1673890715
# 433          53        1.10      BO  1673890721
# 481           0        3.44      US  1673890743
# 492          27        2.51      MX  1673890750
# 530           0        8.55      IN  1673890776
# 532           1       13.51      IN  1673890777
# 533          69        8.59      ZA  1673890778
# 537           4       10.83      ML  1673890780
# 539           0        9.19      BR  1673890781
# 552          99        7.87      CL  1673890787
# 556          96        3.11      NG  1673890789
# 558          56        4.76      TD  1673890790
# 572          13        8.99      NG  1673890796

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
ideal_limited = ideal_clean.loc[:,["City", "Country", "Lat", "Lng", "Humidity"]]

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df = ideal_limited

hotel_df["Hotel Name"] = ''
# Display sample data
hotel_df
# Out:
#                    City Country      Lat      Lng  Humidity Hotel Name
# 5                tahoua      NE  14.8888   5.2692         9
# 11         umm kaddadah      SD  13.6017  26.6876        21
# 84            taoudenni      ML  22.6783  -3.9836        17
# 149                atar      MR  20.5169 -13.0499        10
# 166         panguipulli      CL -39.6333 -72.3333        22
# 198               kutum      SD  14.2000  24.6667        20
# 251               adrar      MR  20.5022 -10.0711        14
# 268               uyuni      BO -20.4597 -66.8250        17
# 273               bilma      NE  18.6853  12.9164        23
# 277  comodoro rivadavia      AR -45.8667 -67.5000        25
# 278               zemio      CF   5.0314  25.1361        24
# 290              rincon      US  32.2960 -81.2354        27
# 303              sindgi      IN  16.9167  76.2333        29
# 330        dogondoutchi      NE  13.6393   4.0287        15
# 381            tessalit      ML  20.1986   1.0114        15
# 388               gambo      CF   4.6482  22.2633        29
# 399         tallahassee      US  30.4383 -84.2807        34
# 420     sancti spiritus      CU  21.9297 -79.4425        34
# 433          eucaliptus      BO -17.5833 -67.5167        19
# 481      mount pleasant      US  32.7941 -79.8626        28
# 492          rio blanco      MX  18.8333 -97.1500        26
# 530             kalavad      IN  22.2167  70.3833        23
# 532             mangrol      IN  21.1167  70.1167        33
# 533           colesberg      ZA -30.7200  25.0972        16
# 537             goundam      ML  16.4145  -3.6708        11
# 539    pinheiro machado      BR -31.5783 -53.3811        32
# 552             carahue      CL -38.7000 -73.1667        31
# 556               keffi      NG   8.8486   7.8736        14
# 558              beboto      TD   8.2668  16.9390        18
# 572        birnin kebbi      NG  12.4539   4.1975        15

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories": "accommodation.hotel",
    "api_key": geoapify_key,
    "language": 'en'
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = hotel_df.loc[index, "Lat"]
    longitude = hotel_df.loc[index, "Lng"]

    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    filters = f"circle:{longitude},{latitude},{radius}"
    bias = f"proximity:{longitude},{latitude}"    
    params["filter"] = filters
    params["bias"] = bias
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# tahoua - nearest hotel: Hotel Bungalow
# umm kaddadah - nearest hotel: No hotel found
# taoudenni - nearest hotel: No hotel found
# atar - nearest hotel: فندق سكليل
# panguipulli - nearest hotel: Cabañas Villa Los Encinos
# kutum - nearest hotel: No hotel found
# adrar - nearest hotel: No hotel found
# uyuni - nearest hotel: Hostel Jerian
# bilma - nearest hotel: No hotel found
# comodoro rivadavia - nearest hotel: No hotel found
# zemio - nearest hotel: No hotel found
# rincon - nearest hotel: No hotel found
# sindgi - nearest hotel: Sangam Hotel
# dogondoutchi - nearest hotel: Maison Alheri
# tessalit - nearest hotel: No hotel found
# gambo - nearest hotel: No hotel found
# tallahassee - nearest hotel: The Governors Inn
# sancti spiritus - nearest hotel: Hostal Nuris
# eucaliptus - nearest hotel: No hotel found
# mount pleasant - nearest hotel: Old Village Post House
# rio blanco - nearest hotel: Hotel La Laguna
# kalavad - nearest hotel: No hotel found
# mangrol - nearest hotel: No hotel found
# colesberg - nearest hotel: No hotel found
# goundam - nearest hotel: No hotel found
# pinheiro machado - nearest hotel: No hotel found
# carahue - nearest hotel: No hotel found
# keffi - nearest hotel: No hotel found
# beboto - nearest hotel: No hotel found
# birnin kebbi - nearest hotel: Fab Hotel
#                    City Country      Lat      Lng  Humidity  \
# 5                tahoua      NE  14.8888   5.2692         9
# 11         umm kaddadah      SD  13.6017  26.6876        21
# 84            taoudenni      ML  22.6783  -3.9836        17
# 149                atar      MR  20.5169 -13.0499        10
# 166         panguipulli      CL -39.6333 -72.3333        22
# 198               kutum      SD  14.2000  24.6667        20
# 251               adrar      MR  20.5022 -10.0711        14
# 268               uyuni      BO -20.4597 -66.8250        17
# 273               bilma      NE  18.6853  12.9164        23
# 277  comodoro rivadavia      AR -45.8667 -67.5000        25
# 278               zemio      CF   5.0314  25.1361        24
# 290              rincon      US  32.2960 -81.2354        27
# 303              sindgi      IN  16.9167  76.2333        29
# 330        dogondoutchi      NE  13.6393   4.0287        15
# 381            tessalit      ML  20.1986   1.0114        15
# 388               gambo      CF   4.6482  22.2633        29
# 399         tallahassee      US  30.4383 -84.2807        34
# 420     sancti spiritus      CU  21.9297 -79.4425        34
# 433          eucaliptus      BO -17.5833 -67.5167        19
# 481      mount pleasant      US  32.7941 -79.8626        28
# 492          rio blanco      MX  18.8333 -97.1500        26
# 530             kalavad      IN  22.2167  70.3833        23
# 532             mangrol      IN  21.1167  70.1167        33
# 533           colesberg      ZA -30.7200  25.0972        16
# 537             goundam      ML  16.4145  -3.6708        11
# 539    pinheiro machado      BR -31.5783 -53.3811        32
# 552             carahue      CL -38.7000 -73.1667        31
# 556               keffi      NG   8.8486   7.8736        14
# 558              beboto      TD   8.2668  16.9390        18
# 572        birnin kebbi      NG  12.4539   4.1975        15
#
#                     Hotel Name
# 5               Hotel Bungalow
# 11              No hotel found
# 84              No hotel found
# 149                 فندق سكليل
# 166  Cabañas Villa Los Encinos
# 198             No hotel found
# 251             No hotel found
# 268              Hostel Jerian
# 273             No hotel found
# 277             No hotel found
# 278             No hotel found
# 290             No hotel found
# 303               Sangam Hotel
# 330              Maison Alheri
# 381             No hotel found
# 388             No hotel found
# 399          The Governors Inn
# 420               Hostal Nuris
# 433             No hotel found
# 481     Old Village Post House
# 492            Hotel La Laguna
# 530             No hotel found
# 532             No hotel found
# 533             No hotel found
# 537             No hotel found
# 539             No hotel found
# 552             No hotel found
# 556             No hotel found
# 558             No hotel found
# 572                  Fab Hotel

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
#map_plot1 = hotel_df.hvplot.points(
#    "Lng",
#    "Lat",
#    geo = True,
#    tiles = "Hotel Name",
#    frame_width = 700,
#    frame_height = 500,
#    size = "Humidity",
#    scale = 0.01,
#    color = "City"
#)
# Display the map
#map_plot1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
